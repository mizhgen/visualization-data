# %% [markdown]
# ## Подключение необходимых библиотек

# %%
from plotnine import *
from plotnine.data import *

import numpy as np
import pandas as pd

import warnings

# %% [markdown]
# ## Тестовый датафрейм "mpg"

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# ## Простейшая визуализация с использованиме geom_point по осям displ и hwy

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"))
# Out:
# <ggplot: (8789932609588)>

# %% [markdown]
# ### Постройте два графика: в одном из них одна из осей должна быть соответствовать столбцу с элементами-категориями, во втором – обе (например, "class" и "drv")

# %%
ggplot(data=mpg) + geom_point(mapping=aes(x="manufacturer", y="cty"))
# Out:
# <ggplot: (8789932526219)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="class", y="drv"))
# Out:
# <ggplot: (8789932473459)>

# %% [markdown]
# ## Добавим красок, оттенков и форм в графики

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", color="class"))
# Out:
# <ggplot: (8789932438007)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", alpha="manufacturer"))
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/scales/scale_alpha.py:68: PlotnineWarning: Using alpha for a discrete variable is not advised.
# <ggplot: (8789932385003)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy", shape="manufacturer"))
# Out:
# /usr/local/lib/python3.8/dist-packages/mizani/palettes.py:647: UserWarning: Palette can return a maximum of 13 values. 15 values requested.
# /usr/local/lib/python3.8/dist-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 61 rows containing missing values.
# /usr/local/lib/python3.8/dist-packages/mizani/palettes.py:647: UserWarning: Palette can return a maximum of 13 values. 15 values requested.
# /usr/local/lib/python3.8/dist-packages/plotnine/guides/guides.py:261: PlotnineWarning: geom_point legend : Removed 2 rows containing missing values.
# <ggplot: (8789932344869)>

# %% [markdown]
# ### Попробуйте сделать два графика: в одном размер точек будет соответствовать столбцу с элементами-категориями, во втором – столбцу с элементами-значениями

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="hwy", y="manufacturer", stroke='year'))
# Out:
# <ggplot: (8789932498658)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="hwy", y="manufacturer", stroke='cyl'))
# Out:
# <ggplot: (8789932239041)>

# %% [markdown]
# ## А что если сделать использовать в качестве источника визуального свойства "форма" непрерывную категорию (например hwy)?

# %%
ggplot(mpg) + geom_point(mapping = aes(x="hwy", y="cty", scale_fill_manual = "cty"))

# Форма всех точек одинакова
# Out:
# <ggplot: (8789930614414)>

# %% [markdown]
# ### Попробуйте сделать график с визуальным элементом, заданным условным оператором (например, color="displ < 5")

# %%
ggplot(mpg) + geom_point(mapping = aes(x='cyl', y='displ', color='hwy < 20'))
# Out:
# <ggplot: (8789930615869)>

# %% [markdown]
# ### Попробуйте поэкспериментировать с графиками, где одной категории соответствуют различные визуальные элементы (пример ниже). Попробуйте привести пример, когда это имеет смысл.

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", stroke="hwy"))
# Out:
# <ggplot: (8789930611902)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="manufacturer", stroke="hwy", color="manufacturer"))
# Out:
# <ggplot: (8789930500654)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="hwy", y="cyl", shape='manufacturer', color='cty'))
# Out:
# /usr/local/lib/python3.8/dist-packages/mizani/palettes.py:647: UserWarning: Palette can return a maximum of 13 values. 15 values requested.
# /usr/local/lib/python3.8/dist-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 61 rows containing missing values.
# /usr/local/lib/python3.8/dist-packages/mizani/palettes.py:647: UserWarning: Palette can return a maximum of 13 values. 15 values requested.
# /usr/local/lib/python3.8/dist-packages/plotnine/guides/guides.py:261: PlotnineWarning: geom_point legend : Removed 2 rows containing missing values.
# <ggplot: (8789930441560)>

# %% [markdown]
# ## Использование панелей при визуализации

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_wrap("class", nrow=2)
# Out:
# <ggplot: (8789930504424)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy")) +\
facet_grid("drv ~ cyl")
# Out:
# <ggplot: (8789930615830)>

# %% [markdown]
# ### Что если использовать категорию с непрерывными значениями (например, hwy) для разделения на панели?

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="hwy", y="cyl")) +\
facet_wrap("cty", nrow=3)
# Out:
# <ggplot: (8789927470918)>

# %% [markdown]
# ### Можно сделать только вертикальные или только горизонтальные панели, если использовать конструкцию типа (". ~ <категория>")

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="hwy", y="cyl")) +\
facet_grid(". ~ manufacturer")
# Out:
# <ggplot: (8789932509299)>

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="hwy", y="cyl")) +\
facet_grid("manufacturer ~ .")
# Out:
# <ggplot: (8789927044485)>

# %% [markdown]
# ### Что лучше использовать: цвета или панели? А для большого набора?

# %% [markdown]
# ## geom_smooth() позволяет получить сглаженную среднюю (в том числе, с доверительным интервалом).abs
# ### (это не сработает без библиотеки scikit-misc, и может не сработать даже с ней)

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"))
# Out:
# <ggplot: (8789930336684)>

# %%
ggplot(data=mpg) +\
geom_smooth(mapping=aes(x="displ", y="hwy"))
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/stats/smoothers.py:310: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
# <ggplot: (8789930398546)>

# %%
ggplot(data=mpg) +\
geom_smooth(mapping=aes(x="displ", y="hwy", linetype="drv"))
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/stats/smoothers.py:310: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
# <ggplot: (8789930254201)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) +\
geom_point() +\
geom_smooth(mapping=aes(linetype="drv"))
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/stats/smoothers.py:310: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
# <ggplot: (8789927539944)>

# %% [markdown]
# ## Визуальные отображения в функции ggplot будут распространяться на все графики. Отдельные свойства каждого геометрического отображения будут относиться только к нему.

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="class")) +\
geom_smooth()
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/stats/smoothers.py:310: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
# <ggplot: (8789930257330)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +\
geom_point(mapping=aes(color="class")) +\
geom_smooth(data=mpg.loc[mpg["class"] == "subcompact"], se=False)
# Out:
# <ggplot: (8789927622479)>

# %% [markdown]
# ## Попробуйте скомбинировать разные свойства разных слоёв

# %%
ggplot(data=mpg, mapping=aes(x="hwy", y="displ")) + geom_point(mapping=aes(color="cty")) + geom_smooth(data=mpg.loc[mpg["trans"] == "auto(av)"], se=False)
# Out:
# <ggplot: (8789926945428)>

# %% [markdown]
# # Какое геометрическое отображение вы будете использовать, чтобы нарисовать линейную диаграмму (обычный линейный график)?

# %%
ggplot(data=mpg) + geom_smooth(mapping=aes(x="cty", y="hwy"))
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/stats/smoothers.py:310: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
# <ggplot: (8789926911007)>

# %% [markdown]
# ### Подберите подходящий код под следующие графики:
# <img src="supp/p1.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p2.png" alt="Drawing" style="width: 350px;"/></br>
# <img src="supp/p3.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p4.png" alt="Drawing" style="width: 350px;"/></br>
# <img src="supp/p5.png" alt="Drawing" style="width: 350px;"/>
# <img src="supp/p6.png" alt="Drawing" style="width: 350px;"/>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) + geom_point() + geom_smooth()
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/stats/smoothers.py:310: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
# <ggplot: (8789926890867)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) +geom_point() + geom_smooth(mapping=aes(group="drv"), se=False)
# Out:
# <ggplot: (8789926907760)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) + geom_point() + geom_smooth(mapping=aes(), se=False)
# Out:
# <ggplot: (8789926832306)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) + geom_point() + geom_smooth(mapping=aes(x="displ", y="hwy", group=1), se=False)
# Out:
# <ggplot: (8789930306088)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy", color="drv")) + geom_point() + geom_smooth(mapping=aes(linetype="drv", color="drv"))
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/stats/smoothers.py:310: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
# <ggplot: (8789927136720)>

# %%
ggplot(data=mpg, mapping=aes(x="displ", y="hwy")) + geom_point(color="white", size=4) + geom_point(mapping=aes(color="drv"))
# Out:
# <ggplot: (8789932438333)>

# %% [markdown]
# ## Статистические свойства элементов категорий

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut"))
# Out:
# <ggplot: (8789927082707)>

# %% [markdown]
# ### Что делает geom_col()? Чем он отличается от geom_bar()?

# %%
# geom_col() - показывает суммарное количество признака (y), для наблюдений, разбитых на группы по признаку (x)

# geom_bar() - показывает количество наблюдений, имеющих признак (y), для наблюдений, разбитых на группы по признаку (x)

# %%
ggplot(data=diamonds) +\
geom_col(mapping=aes(x="cut", y="clarity"))
# Out:
# <ggplot: (8789927238530)>

# %% [markdown]
# ### Что произойдёт, если
# 'ggplot(data=diamonds) +\
# 'geom_bar(mapping=aes(x="cut", y="..prop.."), group=1)
# или
# ggplot(data=diamonds) +\
# geom_bar(mapping=aes(x="cut", fill="color", y="..prop.."))
# ### запустить без "group=1"? Почему?

# %%
ggplot(data=diamonds) + geom_bar(mapping=aes(x="cut", y="..prop.."), group=1)
# Out:
# <ggplot: (8789932504531)>

# %%
ggplot(data=diamonds) + geom_bar(mapping=aes(x="cut", y="..prop.."))

# если убрать group=1 изображения не будут приведены к одной группе
# Out:
# <ggplot: (8789932549030)>

# %% [markdown]
# ## Модные графики с красивыми цветами

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="cut"))
# Out:
# <ggplot: (8789927625882)>

# %% [markdown]
# ## При добавлении новых категорий в качестве цвета появляется новая функциональность

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"))
# Out:
# <ggplot: (8789932260952)>

# %%
ggplot(data=diamonds, mapping=aes(x="cut", colour="clarity")) +\
geom_bar(fill=None, position="identity")
# Out:
# <ggplot: (8789932382597)>

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"), position="fill")
# Out:
# <ggplot: (8789930308115)>

# %%
ggplot(data=diamonds) +\
geom_bar(mapping=aes(x="cut", fill="clarity"), position="dodge")
# Out:
# <ggplot: (8789926866378)>

# %% [markdown]
# ## Добавим jitter в scatter!

# %%
ggplot(data=mpg) +\
geom_point(mapping=aes(x="displ", y="hwy"), position="jitter")
# Out:
# <ggplot: (8789926909341)>

# %% [markdown]
# ### Зачем тут coord_fixed()? Что делает geom_abline()?

# %%
ggplot(data=mpg, mapping=aes(x="cty", y="hwy")) +\
geom_point() +\
geom_abline() +\
coord_fixed()
# Out:
# <ggplot: (8789927494644)>

# %% [markdown]
# # Творческое задание
# ## Попробуйте использовать изученные средства plotnine для своего датасета (необязательно много и пока не надо строить сложные графики)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
sport_cars = pd.read_csv("/content/drive/MyDrive/sport_cars_characteristics.csv")

# %%
sport_cars
# Out:
#                                 name  sports_car    suv  wagon  minivan  \
# 0                 Chevrolet Aveo 4dr       False  False  False    False
# 1        Chevrolet Aveo LS 4dr hatch       False  False  False    False
# 2             Chevrolet Cavalier 2dr       False  False  False    False
# 3             Chevrolet Cavalier 4dr       False  False  False    False
# 4          Chevrolet Cavalier LS 2dr       False  False  False    False
# ..                               ...         ...    ...    ...      ...
# 423         Nissan Titan King Cab XE       False  False  False    False
# 424                      Subaru Baja       False  False  False    False
# 425                    Toyota Tacoma       False  False  False    False
# 426     Toyota Tundra Regular Cab V6       False  False  False    False
# 427  Toyota Tundra Access Cab V6 SR5       False  False  False    False
#
#      pickup  all_wheel  rear_wheel   msrp  dealer_cost  eng_size  ncyl  \
# 0     False      False       False  11690        10965       1.6     4
# 1     False      False       False  12585        11802       1.6     4
# 2     False      False       False  14610        13697       2.2     4
# 3     False      False       False  14810        13884       2.2     4
# 4     False      False       False  16385        15357       2.2     4
# ..      ...        ...         ...    ...          ...       ...   ...
# 423    True       True       False  26650        24926       5.6     8
# 424    True       True       False  24520        22304       2.5     4
# 425    True      False        True  12800        11879       2.4     4
# 426    True      False        True  16495        14978       3.4     6
# 427    True       True       False  25935        23520       3.4     6
#
#      horsepwr  city_mpg  hwy_mpg  weight  wheel_base  length  width
# 0         103      28.0     34.0  2370.0        98.0   167.0   66.0
# 1         103      28.0     34.0  2348.0        98.0   153.0   66.0
# 2         140      26.0     37.0  2617.0       104.0   183.0   69.0
# 3         140      26.0     37.0  2676.0       104.0   183.0   68.0
# 4         140      26.0     37.0  2617.0       104.0   183.0   69.0
# ..        ...       ...      ...     ...         ...     ...    ...
# 423       305      14.0     18.0  5287.0       140.0     NaN    NaN
# 424       165      21.0     28.0  3485.0       104.0     NaN    NaN
# 425       142      22.0     27.0  2750.0       103.0     NaN    NaN
# 426       190      16.0     20.0  3925.0       128.0     NaN    NaN
# 427       190      14.0     17.0  4435.0       128.0     NaN    NaN
#
# [428 rows x 19 columns]

# %%
ggplot(data=sport_cars, mapping = aes(x='city_mpg', y='hwy_mpg', color='weight')) + geom_point() + geom_smooth(mapping=aes(x='city_mpg', y='hwy_mpg', group=1), se=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 14 rows containing missing values.
# <ggplot: (8789930272323)>

# %%
ggplot(data=sport_cars) +\
geom_col(mapping=aes(x="ncyl", y = 'dealer_cost'))
# Out:
# <ggplot: (8789927505945)>

# %%
ggplot(data=sport_cars, mapping = aes(x='weight', y='horsepwr', shape ='all_wheel', color='dealer_cost')) + geom_point() + geom_smooth(mapping=aes(x='weight', y='horsepwr', group=1), se=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 2 rows containing missing values.
# <ggplot: (8789930595271)>
